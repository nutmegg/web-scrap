# %%
import requests
import PyPDF2  
import camelot

# %%
url = "https://nirfcdn.azureedge.net/2020/pdf/Engineering/IR-E-C-48145.pdf"

# %%
data=requests.get(url)

# %%
with open('IR-E-U-0456.pdf','wb') as f:
    f.write(data.content)

# %%
tables = camelot.read_pdf('IR-E-U-0456.pdf')

# %%
tables[1].df
# Out:
#                0                                                1  \
# 0  Academic Year  No. of first year\nstudents intake in the\nyear
# 1        2013-14                                              240
# 2        2014-15                                              360
# 3        2015-16                                              360
#
#                                                    2              3  \
# 0  No. of first year\nstudents admitted in\nthe year  Academic Year
# 1                                                239        2014-15
# 2                                                356        2015-16
# 3                                                355        2016-17
#
#                                                   4              5  \
# 0  No. of students\nadmitted through\nLateral entry  Academic Year
# 1                                                24        2016-17
# 2                                                41        2017-18
# 3                                                42        2018-19
#
#                                                    6                        7  \
# 0  No. of students\ngraduating in\nminimum stipul...  No. of students\nplaced
# 1                                                244                      196
# 2                                                360                      235
# 3                                                353                      254
#
#                                                    8  \
# 0  Median salary of\nplaced\ngraduates(Amount in\...
# 1             315000(Three lakhs\nFifteen thousands)
# 2             315000(Three lakhs\nFifteen thousands)
# 3              380000(Three lakhs\nEighty thousands)
#
#                                                9
# 0  No. of students\nselected for Higher\nStudies
# 1                                             20
# 2                                             25
# 3                                             23

# %%
int(tables[1].df[1][1])
# Out:
# 240

# %%
tables[0].df
# Out:
#                               0                      1  \
# 0  (All programs\nof all years)  No. of Male\nStudents
# 1      UG [4 Years\nProgram(s)]                      0
#
#                          2               3  \
# 0  No. of Female\nStudents  Total Students
# 1                     1557            1557
#
#                                           4  \
# 0  Within State\n(Including male\n& female)
# 1                                      1325
#
#                                            5  \
# 0  Outside State\n(Including male\n& female)
# 1                                        232
#
#                                               6  \
# 0  Outside\nCountry\n(Including male\n& female)
# 1                                             0
#
#                                                    7  \
# 0  Economically\nBackward\n(Including male\n& fem...
# 1                                                154
#
#                                                    8  \
# 0  Socially\nChallenged\n(SC+ST+OBC\nIncluding ma...
# 1                                                501
#
#                                                    9  \
# 0  No. of students\nreceiving full\ntuition fee\n...
# 1                                                147
#
#                                                   10  \
# 0  No. of students\nreceiving full\ntuition fee\n...
# 1                                                 26
#
#                                                   11  \
# 0  No. of students\nreceiving full\ntuition fee\n...
# 1                                                 16
#
#                                                   12
# 0  No. of students\nwho are not\nreceiving full\n...
# 1                                                466

# %%
tables[1].df
# Out:
#                0                                                1  \
# 0  Academic Year  No. of first year\nstudents intake in the\nyear
# 1        2013-14                                              240
# 2        2014-15                                              360
# 3        2015-16                                              360
#
#                                                    2              3  \
# 0  No. of first year\nstudents admitted in\nthe year  Academic Year
# 1                                                239        2014-15
# 2                                                356        2015-16
# 3                                                355        2016-17
#
#                                                   4              5  \
# 0  No. of students\nadmitted through\nLateral entry  Academic Year
# 1                                                24        2016-17
# 2                                                41        2017-18
# 3                                                42        2018-19
#
#                                                    6                        7  \
# 0  No. of students\ngraduating in\nminimum stipul...  No. of students\nplaced
# 1                                                244                      196
# 2                                                360                      235
# 3                                                353                      254
#
#                                                    8  \
# 0  Median salary of\nplaced\ngraduates(Amount in\...
# 1             315000(Three lakhs\nFifteen thousands)
# 2             315000(Three lakhs\nFifteen thousands)
# 3              380000(Three lakhs\nEighty thousands)
#
#                                                9
# 0  No. of students\nselected for Higher\nStudies
# 1                                             20
# 2                                             25
# 3                                             23

# %%
url.split('/')[-1]
# Out:
# 'IR-E-C-48145.pdf'

# %%
x = tables[2].df

# %%
x[2][3]
# Out:
# '0'

# %%
x
# Out:
#                                                    0        1               2  \
# 0  Ph.D (Student pursuing doctoral program till 2...
# 1                                                              Total Students
# 2                                          Full Time                        0
# 3                                          Part Time                        0
# 4  No. of Ph.D students graduated (including Inte...
# 5                                                     2018-19         2017-18
# 6                                          Full Time        0               0
# 7                                          Part Time        0               0
#
#          3
# 0
# 1
# 2
# 3
# 4
# 5  2016-17
# 6        0
# 7        0
